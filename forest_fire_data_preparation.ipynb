# %%
import sys
# !{sys.executable} -m pip install geopandas
# !pip install folium

# %% [markdown]
# Load Fire Points Dataset

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.geometry import Point
import os

if os.path.exists("data/canada_fire_grid.csv"):
    print("canada_fire_grid.csv already exists, skipping regeneration "
          "(raw NFDB shapefile is no longer available locally)")
    grid_gdf = pd.read_csv("data/canada_fire_grid.csv")
else:
    fires_gdf = gpd.read_file("/Users/taimoorkiani/Downloads/NFDB_point/NFDB_point_20250519.shp")

    #only take necessary cols from dataset
    fires_gdf = fires_gdf[["LATITUDE", "LONGITUDE", "REP_DATE", "SIZE_HA"]]

    #convert date to pandas datetime to filter/sort easily
    fires_gdf["REP_DATE"] = pd.to_datetime(fires_gdf["REP_DATE"])

    # Convert lat/lon coordinates into Point objects that GeoDataFrame can use for spatial queries
    fires_gdf = gpd.GeoDataFrame(
        fires_gdf, 
        geometry=gpd.points_from_xy(fires_gdf["LONGITUDE"], fires_gdf["LATITUDE"]),
        crs="EPSG:4326"  #standard lat/lon (GPS coordinates)
    )

    #create a Canada lat/long grid
    min_lat, max_lat = 41.0, 83.0
    min_lon, max_lon = -141.0, -52.0

    #step size(degrees) 0.5 ~ 50-60km, creates evenly spaced grid points
    lat_steps = np.arange(min_lat, max_lat, 0.5)
    lon_steps = np.arange(min_lon, max_lon, 0.5)

    #create all possible grid points
    grid_points = []
    for lat in lat_steps:
        for lon in lon_steps:
         grid_points.append((lat, lon))

    #convert list of tuples to DataFrame
    grid_df = pd.DataFrame(grid_points, columns=["lat", "lon"])

    #create a geometry column for grid points(new GeoDataFrame)
    grid_gdf = gpd.GeoDataFrame(
        grid_df, #Original grid data

        #List comprehension creates Point object for each (lat, lon) pair
        # zip() pairs corresponding elements from two lists
        geometry=[
            Point(lon, lat)  #Point takes (x, y) = (lon, lat)
            for lat, lon in zip(grid_df['lat'], grid_df['lon'])
        ],
        crs="EPSG:4326" # Same coordinate system as fire data
    )

    # Reproject the grid to a projected CRS (meters)
    grid_gdf = grid_gdf.to_crs(epsg=3347)

    # Create 25km radius buffer zones around each grid point
    # buffer() only works correctly in a projected CRS (meters)
    grid_gdf['geometry'] = grid_gdf.geometry.buffer(25000)

    # Reproject fire data to match the grid's CRS
    fires_gdf = fires_gdf.to_crs(epsg=3347)

    # sjoin finds all fire points that fall inside each grid cell's buffer
    # predicate='contains' means: keep grid cells whose buffer contains a fire
    joined = gpd.sjoin(grid_gdf, fires_gdf, predicate='contains')


    # Grid cell gets 1 if its index appears in 'joined', else 0
    # .isin() checks if each grid_gdf index exists in joined.index
    grid_gdf["historical_fire"] = grid_gdf.index.isin(joined.index).astype(int)

    #save as csv
    #Drop geometry (CSV can't store shapely objects) before saving
    grid_gdf.drop(columns="geometry").to_csv("data/canada_fire_grid.csv", index=False)

    print("Canada wide grid saved as csv")

# %% [markdown]
# ## Backtest Validation: Ground Truth Construction
#
# The existing `historical_fire` flag above is static (all-time, no dates).
# To backtest the FWI system against real outcomes, we need a date-indexed
# version: for each grid cell, which specific days in 2023 had a fire nearby.

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point

# NFDB fire records for 2023 
fires = pd.read_csv("data/nfdb_fires_2023.csv")
fires['REP_DATE'] = pd.to_datetime(fires['REP_DATE'])

# Drop known bad rows: positive longitudes that fall outside Canada
# entirely a data entry error in the source (~0.8% of records)
before = len(fires)
fires = fires[
    (fires['LONGITUDE'] <= -52.0) & (fires['LONGITUDE'] >= -141.5) &
    (fires['LATITUDE'] >= 41.0) & (fires['LATITUDE'] <= 84.0)
]
print(f"Dropped {before - len(fires)} bad-coordinate rows")

fires_gdf = gpd.GeoDataFrame(
    fires, geometry=gpd.points_from_xy(fires['LONGITUDE'], fires['LATITUDE']),
    crs='EPSG:4326'
).to_crs(epsg=3347)  # meters, same projection used above for the buffer

grid = pd.read_csv("data/canada_fire_grid.csv")
grid_gdf = gpd.GeoDataFrame(
    grid, geometry=[Point(lon, lat) for lat, lon in zip(grid['lat'], grid['lon'])],
    crs='EPSG:4326'
).to_crs(epsg=3347)
grid_gdf['geometry'] = grid_gdf.geometry.buffer(25000)  # same 25km buffer as above

joined = gpd.sjoin(grid_gdf, fires_gdf, predicate='contains')
ground_truth = joined[['lat', 'lon', 'REP_DATE']].drop_duplicates()
ground_truth.to_csv("data/ground_truth_2023.csv", index=False)

print(f"{len(ground_truth)} (cell, date) fire records")
print(f"{ground_truth[['lat','lon']].drop_duplicates().shape[0]} unique cells burned in 2023")

# %% [markdown]
# ## FWI Backtest Engine
#
# Reproduces `fire_risk.py`'s exact FFMC/DMC/DC/ISI/BUI/FWI formulas, with one
# fix: the original uses `datetime.now().month` for the day-length factor,
# which is correct for live daily use (today's history is all recent) but
# silently wrong when replaying a full year of history in one sitting,
# every day would get *today's* month instead of its own. Fixed by reading
# the month from each row's actual date.

# %%
import numpy as np

def sanitize(value, default, min_val, max_val):
    try:
        val = float(value)
        if np.isnan(val) or np.isinf(val):
            return default
        return np.clip(val, min_val, max_val)
    except (ValueError, TypeError):
        return default

def calculate_ffmc(temp, humidity, wind, rain, prev_ffmc=85):
    temp = sanitize(temp, 15, -50, 50)
    humidity = sanitize(humidity, 50, 1, 100)
    wind = sanitize(wind, 10, 0, 100)
    rain = sanitize(rain, 0, 0, 500)
    prev_ffmc = sanitize(prev_ffmc, 85, 0, 101)

    mo = 147.2 * (101 - prev_ffmc) / (59.5 + prev_ffmc)

    if rain > 0.5:
        rf = rain - 0.5
        if mo <= 150:
            mo = mo + 42.5 * rf * np.exp(-100 / (251 - mo)) * (1 - np.exp(-6.93 / rf))
        else:
            mo = (mo + 42.5 * rf * np.exp(-100 / (251 - mo)) * (1 - np.exp(-6.93 / rf))
                  + 0.0015 * (mo - 150) ** 2 * np.sqrt(rf))
        if mo > 250:
            mo = 250

    ed = (0.942 * humidity ** 0.679 + 11 * np.exp((humidity - 100) / 10)
          + 0.18 * (21.1 - temp) * (1 - np.exp(-0.115 * humidity)))

    if mo > ed:
        ko = 0.424 * (1 - (humidity / 100) ** 1.7) + 0.0694 * np.sqrt(wind) * (1 - (humidity / 100) ** 8)
        kd = ko * 0.581 * np.exp(0.0365 * temp)
        m = ed + (mo - ed) * 10 ** (-kd)
    else:
        ew = (0.618 * humidity ** 0.753 + 10 * np.exp((humidity - 100) / 10)
              + 0.18 * (21.1 - temp) * (1 - np.exp(-0.115 * humidity)))
        if mo < ew:
            k1 = 0.424 * (1 - ((100 - humidity) / 100) ** 1.7) + 0.0694 * np.sqrt(wind) * (1 - ((100 - humidity) / 100) ** 8)
            kw = k1 * 0.581 * np.exp(0.0365 * temp)
            m = ew - (ew - mo) * 10 ** (-kw)
        else:
            m = mo

    ffmc = 59.5 * (250 - m) / (147.2 + m)
    ffmc = np.clip(ffmc, 0, 101)
    if np.isnan(ffmc) or np.isinf(ffmc):
        return 85
    return float(ffmc)


def calculate_dmc(temp, humidity, rain, prev_dmc=6, month=7):
    temp = sanitize(temp, 15, -50, 50)
    humidity = sanitize(humidity, 50, 1, 100)
    rain = sanitize(rain, 0, 0, 500)
    prev_dmc = sanitize(prev_dmc, 6, 0, 500)

    if temp < -1.1:
        return prev_dmc

    day_lengths = [-1.6, -1.6, -1.6, 0.9, 3.8, 5.8, 6.4, 5.0, 2.4, 0.4, -1.6, -1.6]
    le = day_lengths[month - 1] if 1 <= month <= 12 else 1.4

    re = prev_dmc
    if rain > 1.5:
        rw = 0.92 * rain - 1.27
        wmi = 20 + 280 / np.exp(0.023 * prev_dmc)
        if prev_dmc <= wmi:
            b = 100 / (0.5 + 0.3 * prev_dmc)
        else:
            b = 14 - 1.3 * np.log(prev_dmc + 1)
        mr = prev_dmc + 1000 * rw / (48.77 + b * rw)
        re = max(0, mr)

    if temp > -1.1:
        k = 1.894 * (temp + 1.1) * (100 - humidity) * le * 0.000001
        dmc = re + 100 * k
    else:
        dmc = re

    dmc = max(0, dmc)
    if np.isnan(dmc) or np.isinf(dmc):
        return 6
    return float(dmc)


def calculate_dc(temp, rain, prev_dc=15, month=7):
    temp = sanitize(temp, 15, -50, 50)
    rain = sanitize(rain, 0, 0, 500)
    prev_dc = sanitize(prev_dc, 15, 0, 1000)

    if temp < -2.8:
        return prev_dc

    lf_day = [-1.6, -1.6, -1.6, 0.9, 3.8, 5.8, 6.4, 5.0, 2.4, 0.4, -1.6, -1.6]
    lf = lf_day[month - 1] if 1 <= month <= 12 else 1.4

    rd = prev_dc
    if rain > 2.8:
        ra = rain
        rw = 0.83 * ra - 1.27
        smi = 800 * np.exp(-prev_dc / 400)
        dr = prev_dc - 400 * np.log(1 + 3.937 * rw / smi)
        rd = max(0, dr)

    if temp > -2.8:
        v = 0.36 * (temp + 2.8) + lf
        v = max(0, v)
        dc = rd + v
    else:
        dc = rd

    dc = max(0, dc)
    if np.isnan(dc) or np.isinf(dc):
        return 15
    return float(dc)


def calculate_isi(wind, ffmc):
    wind = sanitize(wind, 10, 0, 100)
    ffmc = sanitize(ffmc, 85, 0, 101)
    fw = np.exp(0.05039 * wind)
    m = 147.2 * (101 - ffmc) / (59.5 + ffmc)
    ff = 91.9 * np.exp(-0.1386 * m) * (1 + m ** 5.31 / 49300000)
    isi = 0.208 * fw * ff
    if np.isnan(isi) or np.isinf(isi):
        return 1.0
    return float(isi)


def calculate_bui(dmc, dc):
    dmc = sanitize(dmc, 6, 0, 500)
    dc = sanitize(dc, 15, 0, 1000)
    if dmc <= 0.4 * dc:
        bui = 0.8 * dmc * dc / (dmc + 0.4 * dc + 0.001)
    else:
        bui = dmc - (1 - 0.8 * dc / (dmc + 0.4 * dc + 0.001)) * (0.92 + (0.0114 * dmc) ** 1.7)
    bui = max(0, bui)
    if np.isnan(bui) or np.isinf(bui):
        return 10.0
    return float(bui)


def calculate_fwi(isi, bui):
    isi = sanitize(isi, 1, 0, 100)
    bui = sanitize(bui, 10, 0, 500)
    if bui <= 80:
        fd = 0.626 * bui ** 0.809 + 2
    else:
        fd = 1000 / (25 + 108.64 * np.exp(-0.023 * bui))
    b = 0.1 * isi * fd
    if b > 1:
        s = np.exp(2.72 * (0.434 * np.log(b)) ** 0.647)
    else:
        s = b
    if np.isnan(s) or np.isinf(s):
        return 5.0
    return float(s)


def get_danger_class(fwi):
    fwi = sanitize(fwi, 5, 0, 100)
    if fwi < 1:
        return "Very Low", 0.05
    elif fwi < 3:
        return "Low", 0.15
    elif fwi < 7:
        return "Moderate", 0.35
    elif fwi < 17:
        return "High", 0.65
    elif fwi < 30:
        return "Very High", 0.85
    else:
        return "Extreme", 0.95


def run_backtest(weather_df, grid_df):
    """
    weather_df: lat, lon, date (YYYYMMDD int), T2M, RH2M, WS10M, PRECTOTCORR
    grid_df: lat, lon, historical_fire
    Returns one row per location per day: computed FWI codes + danger class.
    """
    hist_lookup = dict(zip(zip(grid_df["lat"], grid_df["lon"]), grid_df["historical_fire"]))
    results = []
    weather_df = weather_df.sort_values(["lat", "lon", "date"])

    for (lat, lon), group in weather_df.groupby(["lat", "lon"]):
        group = group.sort_values("date")
        ffmc, dmc, dc = 85.0, 6.0, 15.0  # official FWI spring-startup defaults

        for _, day in group.iterrows():
            date_str = str(int(day["date"]))
            month = int(date_str[4:6])  # this day's actual month

            temp, humidity, wind, rain = day["T2M"], day["RH2M"], day["WS10M"], day["PRECTOTCORR"]

            ffmc = calculate_ffmc(temp, humidity, wind, rain, ffmc)
            dmc = calculate_dmc(temp, humidity, rain, dmc, month)
            dc = calculate_dc(temp, rain, dc, month)
            isi = calculate_isi(wind, ffmc)
            bui = calculate_bui(dmc, dc)
            fwi = calculate_fwi(isi, bui)
            danger_class, risk_prob = get_danger_class(fwi)

            if hist_lookup.get((lat, lon), 0) == 1:
                risk_prob = min(0.98, risk_prob * 1.15) 

            results.append({
                "lat": lat, "lon": lon, "date": date_str,
                "ffmc": ffmc, "dmc": dmc, "dc": dc, "isi": isi, "bui": bui, "fwi": fwi,
                "danger_class": danger_class, "risk_prob": risk_prob,
            })

    return pd.DataFrame(results)

weather = pd.read_csv("data/nasa_power_weather_filtered.csv")
backtest = run_backtest(weather, grid)
backtest.to_csv("data/fwi_backtest_2023.csv", index=False)
print(f"{len(backtest)} location-days computed")

# %% [markdown]
# ## Feature Engineering for the ML Layer
#
# Adds seasonality, drying trends, and spatial context on top of the raw FWI
# codes. Trends are computed on the FULL series (including the pre-season
# warmup) *before* filtering to 2023, so early-January rows still get a real
# 7-day trend instead of a null.

# %%
PROVINCE_BOUNDS = {  
    'BC': (48.3, -139.1, 60.0, -114.1), 'AB': (49.0, -120.0, 60.0, -110.0),
    'SK': (49.0, -110.0, 60.0, -101.4), 'MB': (49.0, -102.0, 60.0, -88.9),
    'ON': (41.7, -95.2, 56.9, -74.3), 'QC': (45.0, -79.8, 62.6, -57.1),
    'NB': (44.6, -69.1, 48.1, -63.7), 'NS': (43.4, -66.4, 47.1, -59.7),
    'PE': (45.9, -64.4, 47.1, -62.0), 'NL': (46.6, -67.8, 60.4, -52.6),
    'YT': (60.0, -141.0, 69.6, -124.0), 'NT': (60.0, -136.0, 78.8, -102.0),
    'NU': (60.0, -110.0, 83.1, -61.0),
}
PRIORITY_ORDER = ['NL', 'PE', 'NS', 'NB', 'QC', 'ON', 'MB', 'SK', 'AB', 'BC', 'YT', 'NT', 'NU']

def get_province(lat, lon):
    for prov in PRIORITY_ORDER:
        min_lat, min_lon, max_lat, max_lon = PROVINCE_BOUNDS[prov]
        if min_lat <= lat <= max_lat and min_lon <= lon <= max_lon:
            return prov
    return 'Unknown'

df = backtest.copy()
df['date'] = pd.to_datetime(df['date'].astype(str), format='%Y%m%d')
df = df.sort_values(['lat', 'lon', 'date'])

df['day_of_year'] = df['date'].dt.dayofyear
df['month'] = df['date'].dt.month

df['dc_trend_7d'] = df['dc'] - df.groupby(['lat', 'lon'])['dc'].shift(7)
df['bui_trend_7d'] = df['bui'] - df.groupby(['lat', 'lon'])['bui'].shift(7)

df['province'] = df.apply(lambda r: get_province(r['lat'], r['lon']), axis=1)
df = df.merge(grid[['lat', 'lon', 'historical_fire']], on=['lat', 'lon'], how='left')
df['historical_fire'] = df['historical_fire'].fillna(0).astype(int)

# restrict to the real 2023 season now that trends are computed
df = df[df['date'] >= '2023-01-01'].copy()

df.to_csv("data/ml_features_2023.csv", index=False)
print(f"{len(df)} rows, {df.shape[1]} columns")
